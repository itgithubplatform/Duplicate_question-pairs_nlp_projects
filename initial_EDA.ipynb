# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('train.csv')
df.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
df.shape
# Out:
# (404290, 6)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.sample(10)
# Out:
#             id    qid1    qid2  \
# 7097      7097   13878   13879
# 38535    38535   69966   69967
# 148640  148640   74599   46839
# 290515  290515  411811  411812
# 288138  288138  409050   61793
# 125296  125296  202153  202154
# 228773  228773   52949   22217
# 176979  176979  272178  272179
# 3563      3563    7059    7060
# 174956  174956  217962  269504
#
#                                                 question1  \
# 7097    Is a heart rate of 110 beats per minute health...
# 38535   Which operas in an uncommon foreign language a...
# 148640           Are there any other websites like Quora?
# 290515   What are the solutions to reduce rapes in India?
# 288138                 Which is the best business school?
# 125296  Where can I download or watch krishi series dr...
# 228773                 Is there proof of alien life form?
# 176979  Do all the characters in the movie adaptation ...
# 3563                               Is world war 3 likely?
# 174956  Can I sell a book summary? Do I need any permi...
#
#                                                 question2  is_duplicate
# 7097    How does it feel to have increased rate of hea...             0
# 38535   How hard is it to start a life in a country in...             0
# 148640  Are there any websites that has similar functi...             1
# 290515                   How do we reduce rapes in India?             1
# 288138  What are the best MBA business schools in the ...             0
# 125296  How can I download the 'Friends' TV series epi...             0
# 228773                             Does alien life exist?             1
# 176979             Is Hermione Granger necessarily white?             0
# 3563                           How soon is world war III?             1
# 174956  Can I sell a book that is a summary of another...             1

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404290 entries, 0 to 404289
# Data columns (total 6 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   id            404290 non-null  int64
#  1   qid1          404290 non-null  int64
#  2   qid2          404290 non-null  int64
#  3   question1     404289 non-null  object
#  4   question2     404288 non-null  object
#  5   is_duplicate  404290 non-null  int64
# dtypes: int64(4), object(2)
# memory usage: 18.5+ MB

# %%
df.isnull().sum()
# Out:
# id              0
# qid1            0
# qid2            0
# question1       1
# question2       2
# is_duplicate    0
# dtype: int64

# %%
# Distrubution of duplicate and non-duplicate question
print(df['is_duplicate'].value_counts())
print((df['is_duplicate'].value_counts()/df['is_duplicate'].count())*100)
df['is_duplicate'].value_counts().plot(kind='bar')
# Out:
# is_duplicate
# 0    255027
# 1    149263
# Name: count, dtype: int64
# is_duplicate
# 0    63.080215
# 1    36.919785
# Name: count, dtype: float64
# <Axes: xlabel='is_duplicate'>

# %%
qid = pd.Series(df['qid1'].tolist() + df['qid2'].tolist())
print('Number of unique questions',np.unique(qid).shape[0])
x = qid.value_counts()>1
print('Number of questions getting repeated',x[x].shape[0])
# Out:
# Number of unique questions 537933
# Number of questions getting repeated 111780

# %%
#Repeated question histogram
plt.hist(qid.value_counts().values,bins=160)
plt.yscale('log')
plt.show()
